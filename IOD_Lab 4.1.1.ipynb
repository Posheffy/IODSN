# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 4.1.1 Linear Regression

# %% [markdown]
# ## Prediction of House Price Using Linear Regression

# %% [markdown]
# ### Data
#
# The Sacramento real estate transactions file is a list of 985 real estate transactions in the Sacramento area reported over a five-day period, as reported by the Sacramento Bee.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### 1. Explore Data

# %% [markdown]
# Perform EDA on this dataset. Use what you have learned so far. Be creative. List all your findings.

# %%
# Read CSV
df = pd.read_csv("/Users/stephanienduaguba/Documents/DATA/Sacramento_transactions.csv")

# %%
# Shape - Number of rows and columns
df.shape
# Out:
# (985, 12)

# %%
# Head - First 5 rows of dataset
df.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %%
# Tail - Last 5 rows of dataset
df.tail()
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
#             type                     sale_date   price   latitude   longitude
# 980  Residential  Thu May 15 00:00:00 EDT 2008  232425  38.457679 -121.359620
# 981  Residential  Thu May 15 00:00:00 EDT 2008  234000  38.499893 -121.458890
# 982  Residential  Thu May 15 00:00:00 EDT 2008  235000  38.708824 -121.256803
# 983  Residential  Thu May 15 00:00:00 EDT 2008  235301  38.417000 -121.397424
# 984  Residential  Thu May 15 00:00:00 EDT 2008  235738  38.655245 -121.075915

# %%
# Check non-null count and datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   street     985 non-null    object
#  1   city       985 non-null    object
#  2   zip        985 non-null    int64
#  3   state      985 non-null    object
#  4   beds       985 non-null    int64
#  5   baths      985 non-null    int64
#  6   sq__ft     985 non-null    int64
#  7   type       985 non-null    object
#  8   sale_date  985 non-null    object
#  9   price      985 non-null    int64
#  10  latitude   985 non-null    float64
#  11  longitude  985 non-null    float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 92.5+ KB

# %%
# Set 'zip' to string (object) as this is a categorical data
df['zip'] = df['zip'].astype(str)

# %%
# Recheck datatypes
df.dtypes
# Out:
# street        object
# city          object
# zip           object
# state         object
# beds           int64
# baths          int64
# sq__ft         int64
# type          object
# sale_date     object
# price          int64
# latitude     float64
# longitude    float64
# dtype: object

# %%
# High level stats of the variables
df.describe().T
# Out:
#            count           mean            std          min            25%  \
# beds       985.0       2.911675       1.307932     0.000000       2.000000
# baths      985.0       1.776650       0.895371     0.000000       1.000000
# sq__ft     985.0    1314.916751     853.048243     0.000000     952.000000
# price      985.0  234144.263959  138365.839085  1551.000000  145000.000000
# latitude   985.0      38.607732       0.145433    38.241514      38.482717
# longitude  985.0    -121.355982       0.138278  -121.551704    -121.446127
#
#                      50%            75%            max
# beds            3.000000       4.000000       8.000000
# baths           2.000000       2.000000       5.000000
# sq__ft       1304.000000    1718.000000    5822.000000
# price      213750.000000  300000.000000  884790.000000
# latitude       38.626582      38.695589      39.020808
# longitude    -121.376220    -121.295778    -120.597599

# %% [markdown]
# The minimum value for beds, baths and sq__ft is seen to be zero and that does not look right.

# %%
# Recheck missing data
df.isnull().sum().any()
# Out:
# False

# %%
# Check if rows with zero 'beds', 'baths' and 'sq__ft' are the same
# Rows where 'beds' is zero
zero_beds_rows = df[df['beds'] == 0]

# Rows where 'baths' is zero
zero_baths_rows = df[df['baths'] == 0]

# Rows where 'sq__ft' is zero
zero_sqft_rows = df[df['sq__ft'] == 0]

# Check if row numbers are the same
intersection = zero_beds_rows.index.intersection(zero_baths_rows.index).intersection(zero_sqft_rows.index)

if not intersection.empty:
    print("Row numbers with zero 'beds', 'baths', and 'sq__ft' are the same.")
else:
    print("There are no rows with zero 'beds', 'baths', and 'sq__ft' in common.")
# Out:
# Row numbers with zero 'beds', 'baths', and 'sq__ft' are the same.

# %%
# Plot of unique categories of 'type'
df['type'].value_counts().plot(kind='bar')
plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Plot of House Types')
plt.show()

# %%
# Check data where 'type' equals 'Unkown'
df[df['type'] == 'Unkown']
# Out:
#                 street             city    zip state  beds  baths  sq__ft  \
# 757  6007 MARYBELLE LN  SHINGLE SPRINGS  95682    CA     0      0       0
#
#        type                     sale_date   price  latitude   longitude
# 757  Unkown  Fri May 16 00:00:00 EDT 2008  275000  38.64347 -120.888183

# %%
# Create new 'type' category, 'Plot' for rows with zero 'beds', 'baths' and 'sq__ft'
df.loc[(df['beds'] == 0) & (df['baths'] == 0) & (df['sq__ft'] == 0), 'type'] = 'Plot'

# %%
# Recheck count of 'type' categories
df['type'].value_counts()
# Out:
# Residential     818
# Plot            108
# Condo            46
# Multi-Family     13
# Name: type, dtype: int64

# %% [markdown]
# Note that the newly created 'Plot' category includes where the 'type' was previously 'Unkown'.

# %%
# Check unique categories of 'state'
df['state'].unique()
# Out:
# array(['CA'], dtype=object)

# %% [markdown]
# Given California is the only state in this dataset, the 'state' variable will not be considered in the model.

# %%
# Check unique categories of 'city'
df['city'].value_counts().sort_values().plot(kind='barh', figsize=(10, 8))
plt.xlabel('Count')
plt.ylabel('City')
plt.title('Plot of Cities')
plt.show()

# %%
# Create an interactive map
# Import the necessary libraries
import folium
import pandas as pd

# To use Mapbox tiles in a Folium map, you need to specify your Mapbox access token and use the Mapbox tileset as the tiles parameter.

# Create a Folium map
m = folium.Map(
    location=[38.575764, -121.478851], # Set the initial map center coordinates
    tiles="OpenStreetMap",  # Specify the map tiles (you can replace this with your Mapbox style URL)
    zoom_start=10 # Set the initial zoom level
)

# Add markers to the map based on latitude and longitude coordinates from the DataFrame
for i in range(0, len(df.head(1000))):
    folium.Marker(
        location=[df.iloc[i]['latitude'], df.iloc[i]['longitude']]
    ).add_to(m)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b81431482f04a25d6185540acea4a805 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b81431482f04a25d6185540acea4a805&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b81431482f04a25d6185540acea4a805 = L.map(
#                 &quot;map_b81431482f04a25d6185540acea4a805&quot;,
#                 {
#                     center: [38.575764, -121.478851],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9fb7d2dc7ab463ab5f94e51a9144b4ac = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_b38c46f4e40728ee62dc9db692590386 = L.marker(
#                 [38.631913, -121.434879],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_9a72d2c0a7e6d0622d82cb6c4c0aad1a = L.marker(
#                 [38.478902, -121.431028],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_da34407fae7e1b76a60f0d737d26a497 = L.marker(
#                 [38.618305, -121.443839],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_3422e70847573f2f024ec6c1f51ef233 = L.marker(
#                 [38.616835, -121.439146],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_06096527c018463622421099a4485e47 = L.marker(
#                 [38.51947, -121.435768],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_c9e19d2e911f4efd6871f27cf1b6f43c = L.marker(
#                 [38.662595, -121.327813],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_d325eed2565f6a3ab50b25128b6a269e = L.marker(
#                 [38.681659, -121.351705],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_2c9d77fe93a01a54248ea1c58536697e = L.marker(
#                 [38.535092, -121.481367],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_d8629e32e16d6647a6f572581c11cca3 = L.marker(
#                 [38.621188, -121.270555],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_4b395e9412b682e5c8d9293b5c692e4d = L.marker(
#                 [38.700909, -121.442979],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_9274314fbb6e3de17af2205db3466fc3 = L.marker(
#                 [38.637663, -121.45152],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_54d5f12354a52a70d0e60f0d1b0b1abb = L.marker(
#                 [38.470746, -121.458918],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_ebd98403ef05a79700e59deff493d7e9 = L.marker(
#                 [38.618698, -121.435833],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_a2fa219d27acb5d7c8eb9b2a6551cc36 = L.marker(
#                 [38.482215, -121.492603],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_2a9a2aaefa981a3df839e5846fd4a8a8 = L.marker(
#                 [38.672914, -121.35934],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_ab51e182c3741b165cef60bf1b2812c8 = L.marker(
#                 [38.700051, -121.351278],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_79b9874636fe192272f9515532e1e0e6 = L.marker(
#                 [38.689591, -121.452239],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_6bd7cba90850a234708286ee45a627d5 = L.marker(
#                 [38.679776, -121.314089],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_aed3cf0cb6669ffe07924a28640cc1de = L.marker(
#                 [38.612099, -121.469095],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_d12684a6deba0278837de394d8a27ca7 = L.marker(
#                 [38.689999, -121.46322],
#                 {}
#             ).addTo(map_b81431482f04a25d6185540acea4a805);
#
#
#             var marker_1415d54f6ea6467952a3ecd

# %%
# List of columns headers
df.columns
# Out:
# Index(['street', 'city', 'zip', 'state', 'beds', 'baths', 'sq__ft', 'type',
#        'sale_date', 'price', 'latitude', 'longitude'],
#       dtype='object')

# %%
# Correlation matrix
numeric_columns = ['beds', 'baths', 'sq__ft', 'price']
corr = df[numeric_columns].corr()

# Heatmap showing correlation
sns.heatmap(corr, annot=True)
plt.show()

# %%
# Pairplot of numerical independent variables with price
sns.pairplot(df, y_vars='price', x_vars=['beds', 'baths', 'sq__ft'], kind='reg', height=4);

# %% [markdown]
# The price tends to increase as the number of beds, baths, and square footage increases, indicating a positive correlation.

# %% [markdown]
# ### 2. Predict Price

# %% [markdown]
# We are going to predict `price` from available information.

# %% [markdown]
# #### 2.1 What is the Target Variable? Why?

# %% [markdown]
# ANSWER:
#
# Price is the target variable - the 'price' aligns with the predictive objective of the model and would also be the most relevant feature to answer a business question.

# %% [markdown]
# #### 2.2 List all possible variables which might be Predictor variable.

# %% [markdown]
# ANSWER:
#
# Possible predictor variables include: 'beds', 'baths', 'sq__ft', 'type'

# %% [markdown]
# #### 2.3 Find correlation between variables
#
# Find correlation between variables. Which is the best predictor? Why? State your reason.

# %%
# Target variable
y = df['price']
# Predictor variables
# X = df[['beds', 'baths', 'sq__ft', 'type']]

# %%
# Function to visualize distribution of numerical variables and correlation to 'price'
def draw_scatter_plot(data, x_col, y_col):
        
    # Extract the specified columns
    x_data = data[x_col]
    y_data = data[y_col]

    # Generate the title based on column names
    title = f"Scatter plot of {x_col} vs {y_col}"

    # Create a scatter plot with hue
    sns.scatterplot(x=x_col, y=y_col, data=data, hue=data['type'])
    
    # Set the title
    plt.title(title)
    
    # Add a grid
    plt.grid(True)
    
    # Add legend and set position
    legend = plt.legend(title="Type")
    legend.set_bbox_to_anchor((1.3, 1.02))
    
    plt.show()

# %%
# Scatter plot of beds vs price
draw_scatter_plot(df, 'beds', 'price')

# %%
# Scatter plot of baths vs price
draw_scatter_plot(df, 'baths', 'price')

# %%
# Scatter plot of sq__ft vs price
draw_scatter_plot(df, 'sq__ft', 'price')

# %%
# Boxplot of categorical variable
sns.boxplot(x="type", y="price", data=df)

# Add labels and a title
plt.xlabel("type")
plt.ylabel("price")
plt.title("Box Plot of type vs price")

# Show the plot
plt.show()

# %%
# Correlation matrix excluding the 'Plot' category
# Define the category to exclude and columns to exclude
excluded_category = 'Plot' 
excluded_columns = ['latitude', 'longitude'] 

# Filter to exclude 'Plot'
filtered_data = df[df['type'] != excluded_category]

# Drop the 'latitude' and 'longitude' from the filtered data
filtered_data = filtered_data.drop(columns=excluded_columns)

# Calculate the correlation matrix
correlation_matrix = filtered_data.corr(numeric_only=True)

# Create a heatmap to visualize the correlation matrix
sns.heatmap(correlation_matrix, annot=True)
plt.title(f'Correlation Matrix (Excluding Category {excluded_category})')

# Show the plot
plt.show()

# %%
# Correlation matrix of only the 'Plot' category
# Define the columns to exclude
excluded_columns = ['latitude', 'longitude', 'beds', 'baths'] 

# Drop the columns from the filtered data
filtered_data = df.drop(columns=excluded_columns)

# Calculate the correlation matrix
correlation_matrix = filtered_data.corr(numeric_only=True)

# Create a heatmap to visualize the correlation matrix
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix of Plot vs Price')

# Show the plot
plt.show()

# %% [markdown]
# ANSWER - Best predictor? Why? Reason?
#
# Square footage (sq__ft) is the best predictor because it impacts all types of properties.
#
# Based on the exploratory data analysis (EDA) and the correlation matrix, the number of bathrooms (baths) exhibits the strongest correlation for residential, condo and multi-family properties. However, considering the high correlation between the number of bathrooms and bedrooms (beds), which can lead to multicollinearity issues, the number of bedrooms could be used as an additional feature for modeling. This choice is made based on practicality, as the number of bedrooms tends to be a more crucial factor in real-world scenarios.

# %% [markdown]
# #### 2.4 What is the simplest way to predict price
#
# So we have information for 985 houses. What is the easiest way to predict price of a house?

# %%
# ANSWER
# Simplest way to predict the price is using the mean
# Mean of price
df['y_hat'] = df['price'].mean()

# %%
X = df['sq__ft']
y = df['price']
yhat = df['y_hat'] #'y_hat' - an estimated value for 'price', in this case, based on mean

# %%
# Function to plot the data with the mean value
def draw_plot(X, y, yhat):
    # Create a figure
    fig = plt.figure(figsize=(10,8))
    # Get the axis of that figure
    ax = plt.gca()
    
    # Plot a scatter plot of it with our data
    ax.scatter(X, y, c='b')
    ax.plot(X, yhat, color='r')
    
    plt.show

# %%
# Plot showing mean as the predicted line
draw_plot(X, y, yhat)

# %% [markdown]
# #### 2.5 Find Residuals
#
# Find difference between actual value and predicted value. Use absolute value.

# %%
# ANSWER
# Mean Absolute Error (residuals)
res = abs(df['price'] - df['y_hat']).mean()
res
# Out:
# 103452.16956891441

# %% [markdown]
# #### 2.6  Predict Using Linear Regression
#
# [Simple Linear Regression](https://en.wikipedia.org/wiki/Simple_linear_regression#Fitting_the_regression_line)
#
# ### $$\hat{y} = \beta_0 + \beta_1 x$$
#
# > ### $$ \beta_1 = \frac{\sum_{i=1}^n (y_i - \bar{y} ) (x_i - \bar{x} )}{\sum_{i=1}^n (x_i - \bar{x})^2} $$
#
# and
#
# > ### $$ \beta_0 = \bar{y} - \beta_1\bar{x} $$
#
# Given variables:
# - $\bar{y}$ : the sample mean of observed values $Y$
# - $\bar{x}$ : the sample mean of observed values $X$

# %% [markdown]
# ##### 2.7 Define X, y
#
# - X = Predictor Variable
# - y = Target Variable

# %%
# ANSWER
# Assigning predictor and target variables
X = df['sq__ft']
y = df['price']

# %% [markdown]
# ##### 2.7.A Calculate beta_1
#
#  ### $$ \beta_1 = \frac{\sum_{i=1}^n (y_i - \bar{y} ) (x_i - \bar{x} )}{\sum_{i=1}^n (x_i - \bar{x})^2} $$

# %%
# ANSWER
# Function to calculate beta_1
def calculate_beta_1(X, y):
    # Calculate the mean of X and y
    xbar = X.mean()
    ybar = y.mean()
    
    # Calculate the numerator of the beta_1 formula
    n = np.sum((y - ybar) * (X - xbar))
    
    # Calculate the denominator of the beta_1 formula
    d = np.sum(np.square(X - xbar))
    
    # Calculate the beta_1 coefficient
    beta_1 = n / d
    
    return beta_1

# %%
# Calculate beta_1
beta_1 = calculate_beta_1(X, y)
beta_1
# Out:
# 54.158639688530755

# %% [markdown]
# ##### 2.7.B Calculate beta_0

# %% [markdown]
# ### $$ \beta_0 = \bar{y} - \beta_1\bar{x} $$

# %%
# ANSWER
# Function to calculate beta_0
def calculate_beta_0(X, y):
    # Calculate the mean of X and y
    xbar = X.mean()
    ybar = y.mean()
    
    # Calculate beta_1 using the provided function
    beta_1 = calculate_beta_1(X, y)
    
    # Calculate beta_0 using the formula: beta_0 = ybar - beta_1 * xbar
    beta_0 = ybar - beta_1 * xbar
    
    return beta_0

# %%
# Calculate beta_0
beta_0 = calculate_beta_0(X, y)
beta_0
# Out:
# 162930.16140699777

# %% [markdown]
# ##### 2.7.C Find Yhat (Predicted Value Using Beta 0 and Beta 1)

# %% [markdown]
# ### $$\hat{y} = \beta_0 + \beta_1 x$$

# %%
# ANSWER
# Function to calculate yhat (estimated value for price)
def calculate_yhat(X, b0, b1):
    return b0 + b1 * X

# %%
# Calculate Yhat
yhat = calculate_yhat(X, beta_0, beta_1)
yhat
# Out:
# 0      208206.784187
# 1      226133.293924
# 2      206040.438599
# 3      209073.322422
# 4      206094.597239
#            ...
# 980    286411.859897
# 981    242922.472227
# 982    228787.067268
# 983    254187.469282
# 984    236694.228663
# Name: sq__ft, Length: 985, dtype: float64

# %% [markdown]
# ##### 2.7.D Find Residuals

# %% [markdown]
# ### $$ \text{residual}_i = y_i - \hat{y}_i$$

# %%
# ANSWER
# Function to calculate residuals
def calculate_residual(y, yhat):
    res = y - yhat
    return res

# %%
# Calculate absolute value for residuals
resi = calculate_residual(y, yhat)
abs(resi)
# Out:
# 0      148984.784187
# 1      157921.293924
# 2      137160.438599
# 3      139766.322422
# 4      124194.597239
#            ...
# 980     53986.859897
# 981      8922.472227
# 982      6212.932732
# 983     18886.469282
# 984       956.228663
# Length: 985, dtype: float64

# %% [markdown]
# ##### 2.7.E Find R-Square
#
# The coefficient $R^2$ is defined as $$ R^2 = 1 - \frac{SS_{res}}{SS_{tot}} $$, where $$ SS_{res} $$ is the residual sum of squares $$ SS_{res} = \sum_{i=1}^n \left(y_i - \hat{y}_i\right)^2 $$ and $$ SS_{res} $$ is the total sum of squares $$ SS_{tot} = \sum_{i=1}^n \left(y_i - \bar{y}\right)^2 $$
#
# The best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse).
#
# **Write a function to calculate R- Square value.**

# %% [markdown]
# The total sum of squares:
#
# ### $$ SS_{tot} = \sum_{i=1}^n \left(y_i - \bar{y}\right)^2 $$
#
# The residual sum of squares:
#
# ### $$ SS_{res} = \sum_{i=1}^n \left(y_i - \hat{y}_i\right)^2 $$
#
# $R^2$:
#
# ### $$ R^2 = 1 - \frac{SS_{res}}{SS_{tot}} $$

# %%
# ANSWER
# Function to calculate total sum of squares
def calculate_total_sum_of_square(y):
    # Calculate the mean of y
    ybar = np.mean(y)
    
    # Calculate the squared differences from the mean
    SStot = np.square(y - ybar)
    
    # Total sum of the squared differences
    SStot = np.sum(SStot)
    
    return SStot

# %%
calculate_total_sum_of_square(y)
# Out:
# 18838783738865.37

# %%
# ANSWER
# Function to calculate residual sum of squares
def calculate_residual_sum_of_square(y, yhat):
    
    # Calculate the squared differences from yhat
    SSres = np.square(y - yhat)
    
    SSres = np.sum(SSres)
    
    return SSres

# %%
calculate_residual_sum_of_square(y, yhat)
# Out:
# 16738500924917.504

# %%
# ANSWER
# Function to calculate r_square
def calculate_r_square(y, yhat):
    SStot = calculate_total_sum_of_square(y)
    SSres = calculate_residual_sum_of_square(y, yhat)
    Rsquare = 1 - (SSres/SStot)
    return Rsquare

# %%
calculate_r_square(y, yhat)
# Out:
# 0.11148717682951459

# %% [markdown]
# ##### 2.7.F [BONUS] Draw Plot of Predicted Line

# %%
# ANSWER
# Plot showing the predicted line
draw_plot(X, y, yhat)

# %% [markdown]
# ##### 2.7.G [BONUS] Draw Plot of Predicted Line With Residuals

# %%
# ANSWER
df['yhat'] = yhat

# %%
# Create figure size
fig = plt.figure(figsize=(15, 8))

# Get the axis
ax = fig.gca()

# Scatter plot for the data points
ax.scatter(x=X, y=y, c='b')

# Line plot for predictions
ax.plot(X, yhat, color='r')

# Iterate over predictions
for _, row in df.iterrows():    
    # Plot a line segment from (row['sq__ft'], row['price']) to (row['sq__ft'], row['yhat']) in green
    plt.plot([row['sq__ft'], row['sq__ft']], [row['price'], row['yhat']], 'g-')

# Add labels and title
ax.set_xlabel('Square Footage')
ax.set_ylabel('Price')
ax.set_title('Scatter Plot with Predictions')

# Show the plot
plt.show()

# %% [markdown]
# ### 3. Predict House Price
#
# Let's assume we have information of following house:
#
# - street:	1140 EDMONTON DR
# - city:	SACRAMENTO
# - zip:	95833
# - state:	CA
# - beds:	3
# - baths:	2
# - sq__ft:	1204
# - type:	Residential
#
# **Predict the price of this house.**

# %%
# ANSWER
Xpred = 1204
Xpred
# Out:
# 1204

# %%
beta_0
# Out:
# 162930.16140699777

# %%
beta_1
# Out:
# 54.158639688530755

# %%
ypred = beta_1 * Xpred + beta_0
ypred
# Out:
# 228137.1635919888

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2023 Institute of Data
#
#
# ---
#
#
#
# ---
